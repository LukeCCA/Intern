# %%
from sklearn import tree
import pandas as pd 
import ast
import pickle
import numpy as np
import re
from ckiptagger import WS
from collections import Counter
import jieba
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
DATASET = "IVR"
WS_SET = ["jieba", "ckip", "mix_0", "mix_1"]
WORD_SEGMENTER = WS_SET[2]

# %% [markdown]
# ---

# %%
if WORD_SEGMENTER == "ckip" or WORD_SEGMENTER.find("mix") != -1:
    ws = WS("../ckiptagger/data")

def get_model_data(file_path):
    df = pd.read_csv(file_path, sep='\t')
#     df = df.sort_values(by=["labels"], ignore_index=True)
    src_labels = sorted(set(df.labels.tolist()))
    df["labels"] = [src_labels.index(l) for l in df.labels.tolist()]
    texts = df["texts"]
    labels = df["labels"]
    num_labels = list(Counter(labels).values())
    
    data = {"corpus":[], "labels":[], "src_texts":[], "src_label":[]}
    
    for i, t in (enumerate(texts)):
        label = labels[i]

        if WORD_SEGMENTER == "ckip":
            sentence_seg = ws([t])[0]
        elif WORD_SEGMENTER == "jieba":
            sentence_seg = jieba.lcut(t)
        elif WORD_SEGMENTER == "mix_0":
            temp = ws([t])[0]
            sentence_seg = []
            for seg_t in temp:
                sentence_seg += jieba.lcut(seg_t)
        elif WORD_SEGMENTER == "mix_1":
            temp = jieba.lcut(t)
            sentence_seg = []
            for seg_t in temp:
                sentence_seg += ws([seg_t])[0]
    
        sentence_seg = [seg_t for seg_t in sentence_seg if seg_t!=' ']
#         seg_texts = ' '.join(sentence_seg)
        
        data["corpus"] += [sentence_seg]
        data["labels"] += [label]
        data["src_texts"] += [t]
        data["src_label"] += [src_labels[label]]
    return data, num_labels # Dict[List], List[Int]

# %%
def get_tf(corpus, data):
    with open("extend_dataset/IVR/tags.pkl", 'rb') as fp:
        tags = pickle.load(fp)

    tf_list = []
    for texts in corpus:
        tf = [0] * len(tags)
        for text in texts:
            i = 0
            for key, value in tags.items():
                value = sorted(value, key=len, reverse=True)
                value = [v for v in value if len(v)==len(text)]
                if value == []:
                    i += 1
                    continue
                big_regex = re.compile('|'.join(map(re.escape, value)))
                temp = big_regex.findall(text)
                tf[i] += len(temp)
                i += 1
        tf_list += [tf]
    data["tf"] = tf_list
    return data

# %%
data_train, num_labels = get_model_data(f"data/{DATASET}/train.tsv")
data_test, _ = get_model_data(f"data/{DATASET}/test.tsv")

# %%
data_train = get_tf(data_train["corpus"], data_train)
data_test = get_tf(data_test["corpus"], data_test)

# %% [markdown]
# ---

# %%
# vec = np.stack(data_train["tf"]) #seg

# all
data_train = pd.read_csv("data/IVR/train.tsv", sep='\t')
vec = np.stack(data_train["tf"].apply(ast.literal_eval).tolist())
data_train["src_label"] = data_train["labels"]
data_test = pd.read_csv("data/IVR/test.tsv", sep='\t')


clf = tree.DecisionTreeClassifier()
clf = clf.fit(vec, data_train["labels"])

# %%
# df = pd.read_csv("data/IVR/class_label.tsv", sep='\t')
with open("extend_dataset/IVR/tags.pkl", 'rb') as fp:
    feature_names = pickle.load(fp)
feature_names = list(feature_names.keys())
label_set = sorted(set(data_train["src_label"]))

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=feature_names,  
                     class_names=label_set,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)
graph.render(filename='tree_seg')
# graph
# tree.plot_tree(clf)
# Out:
# 'tree_seg.pdf'

# %%
def get_prediction(clf, test_data, vectors=None, show_err=False):
#     test_data = test_data[test_data["labels"] != "133_2"]
#     test_data = test_data[test_data["labels"] != "31_2"]
#     test_data = test_data[test_data["labels"] != "31_3"]
#     test_data = test_data[test_data["labels"] != "31_4"]
#     test_data = test_data[test_data["labels"] != "31_5"]

    if vectors is None:
        vectors = test_data.tf.apply(ast.literal_eval).tolist()
        vectors = np.stack(vectors)
    pred = clf.predict(vectors)
    
    if type(pred[0]) == int:
        pred = np.array([label_set[l] for l in pred])
    
    ans = test_data.labels.tolist()
    ans = np.array(ans)
    
    correct = np.count_nonzero(pred==ans)
    acc = correct / len(test_data["labels"])
    print(acc)

    
    if show_err:
        print("ans\tpred\ttexts\tfeatures")
        if type(pred[0]) == int:
            for idx in np.nonzero(pred!=ans)[0]:
                print(f"{ans[idx]}\t{pred[idx]}\t{data_test['corpus'][idx]}\n{[feature_names[i] for i in np.nonzero(data_test['tf'][idx])[0] ]}\n")
        else:
            for idx in np.nonzero(pred!=ans)[0]:
                print(f"{ans[idx]}\t{pred[idx]}\t{data_test['texts'][idx]}\n{ [feature_names[i] for i in np.nonzero(vectors[idx])[0] ] }\n")
        
    return acc

# %%
test_data = pd.read_csv("data/IVR/test.tsv", sep='\t')
# seg
# vec = np.stack(data_test["tf"])
# get_prediction(clf, test_data, vec, show_err=True)
get_prediction(clf, test_data, show_err=True)
# Out:
# 0.6733576642335767
# ans	pred	texts	features
# 111_1	1121	信用卡可刷額度
# ['credit_card', 'debit_card', 'quota', 'spend']
#
# 111_1	1121	信用卡目前額度
# ['credit_card', 'current', 'debit_card', 'quota', 'spend']
#
# 111_1	1121	信用卡目前可用額度
# ['credit_card', 'current', 'debit_card', 'quota', 'remaining', 'spend']
#
# 111_1	1121	信用卡目前可使用的額度
# ['credit_card', 'current', 'debit_card', 'quota', 'spend']
#
# 111_1	1121	卡片目前可用額度
# ['credit_card', 'current', 'debit_card', 'quota', 'remaining', 'spend']
#
# 111_1	1121	卡片目前可刷額度
# ['credit_card', 'current', 'debit_card', 'quota', 'spend']
#
# 111_1	111_2	目前卡片可刷金額
# ['credit_card', 'current', 'debit_card', 'money', 'spend']
#
# 111_1	1121	目前信用卡額度
# ['credit_card', 'current', 'debit_card', 'quota', 'spend']
#
# 111_1	10	卡片刷卡上限
# ['credit_card', 'debit_card', 'spend']
#
# 111_3	121	信用卡帳務產出時間
# ['credit_card', 'debit_card', 'spend']
#
# 111_3	113_3	我的帳單日期
# ['bill', 'date', 'installment']
#
# 111_3	132_7	請問帳單關帳時間
# ['bill']
#
# 111_3	132_2	請問信用卡帳單周期
# ['bill', 'credit_card', 'debit_card', 'installment', 'spend']
#
# 111_3	113_3	請問卡片帳單日期
# ['bill', 'credit_card', 'date', 'debit_card', 'installment']
#
# 111_3	132_2	請問卡片帳單周期
# ['bill', 'credit_card', 'debit_card', 'installment']
#
# 111_3	111_8	請問帳單繳款時間
# ['bill', 'pay']
#
# 111_3	132_7	帳單金額產出時間
# ['bill', 'money']
#
# 111_4	111_5	下期帳單目前要繳哪些
# ['bill', 'current', 'installment', 'next', 'pay']
#
# 111_4	132_7	次月帳單累積的內容明細
# ['bill', 'detail']
#
# 111_4	121	信用卡下個月已刷的明細
# ['already', 'credit_card', 'debit_card', 'detail', 'spend']
#
# 111_4	111_8	信用卡下個月要繳的內容
# ['credit_card', 'debit_card', 'pay', 'spend']
#
# 111_4	121	信用卡目前已經累積的內容
# ['already', 'credit_card', 'current', 'debit_card', 'spend']
#
# 111_4	111_8	卡片下個月要繳的內容
# ['credit_card', 'debit_card', 'pay']
#
# 111_4	113_1	卡片下個月應繳的明細
# ['credit_card', 'debit_card', 'dept', 'detail', 'pay']
#
# 111_5	111_8	幫我查這個月帳單繳款了嗎
# ['bill', 'doubt', 'pay']
#
# 111_5	113_3	我這期個用卡帳單繳了嗎
# ['bill', 'credit_card', 'current', 'debit_card', 'doubt', 'installment', 'pay', 'spend']
#
# 111_5	113_1	有沒有收到信用卡繳款
# ['credit_card', 'debit_card', 'doubt', 'nagative', 'over', 'pay', 'spend']
#
# 111_5	111_8	這個月帳單有扣款成功嗎
# ['bill', 'doubt', 'pay']
#
# 111_5	111_6	信用卡帳單要扣到款項嗎
# ['bill', 'credit_card', 'debit_card', 'doubt', 'pay', 'spend']
#
# 111_5	111_1	我有轉錢到信用卡有進去嗎
# ['credit_card', 'debit_card', 'doubt', 'forward', 'money', 'spend', 'transfer']
#
# 111_5	111_7	有辦自動扣繳有扣到信用卡款項嗎
# ['auto', 'bid', 'credit_card', 'debit_card', 'doubt', 'pay', 'spend']
#
# 111_7	116	玉山帳戶自動繳卡費
# ['account', 'auto', 'bill', 'credit_card', 'debit_card', 'esun', 'pay']
#
# 111_7	116	玉山帳戶自動扣信用卡費
# ['account', 'auto', 'bill', 'credit_card', 'debit_card', 'esun', 'pay', 'spend']
#
# 111_8	111_5	英文轉數字
# ['forward']
#
# 111_8	221	要使用atm轉帳
# ['atm', 'forward', 'spend', 'transfer']
#
# 111_8	132_7	帳單遺失查詢atm轉帳帳戶
# ['account', 'atm', 'bill', 'forward', 'loss', 'query', 'transfer']
#
# 111_8	132_7	帳單遺失轉帳帳戶
# ['account', 'bill', 'forward', 'loss', 'transfer']
#
# 111_8	111_6	網路轉帳繳款信用卡款帳號
# ['account', 'credit_card', 'debit_card', 'forward', 'info', 'pay', 'spend', 'transfer', 'web']
#
# 111_8	111_3	請問信用卡費可否轉帳
# ['bill', 'credit_card', 'debit_card', 'forward', 'spend', 'transfer']
#
# 111_8	111_7	轉帳信用卡繳款
# ['credit_card', 'debit_card', 'forward', 'pay', 'spend', 'transfer']
#
# 111_8	111_7	轉帳繳款信用卡款帳戶
# ['account', 'credit_card', 'debit_card', 'forward', 'pay', 'spend', 'transfer']
#
# 111_8	111_6	信用卡帳單怎麼繳費
# ['bill', 'credit_card', 'debit_card', 'how', 'pay', 'spend']
#
# 111_8	111_6	信用卡繳費方式
# ['bill', 'credit_card', 'debit_card', 'method', 'pay', 'spend']
#
# 111_8	113_3	信用卡如何繳費
# ['bill', 'credit_card', 'debit_card', 'how', 'pay', 'spend']
#
# 111_8	111_5	信用卡可以轉帳繳款嗎
# ['credit_card', 'debit_card', 'doubt', 'forward', 'pay', 'spend', 'transfer']
#
# 111_8	111_5	信用卡可以到ATM繳嗎
# ['credit_card', 'debit_card', 'doubt', 'pay', 'spend']
#
# 111_8	111_5	信用卡可以郵局繳嗎
# ['credit_card', 'debit_card', 'doubt', 'other_bank', 'pay', 'post', 'spend']
#
# 111_8	111_6	信用卡費怎麼繳費
# ['bill', 'credit_card', 'debit_card', 'how', 'pay', 'spend']
#
# 111_8	111_6	信用卡費繳費方式
# ['bill', 'credit_card', 'debit_card', 'method', 'pay', 'spend']
#
# 111_8	111_6	信用卡費如何繳費
# ['bill', 'credit_card', 'debit_card', 'how', 'pay', 'spend']
#
# 113_1	111_2	信用卡費多少
# ['bill', 'credit_card', 'debit_card', 'how_much', 'spend', 'under']
#
# 113_1	111_1	信用卡款多少
# ['credit_card', 'debit_card', 'how_much', 'spend', 'under']
#
# 113_1	111_1	信用卡款多少錢
# ['credit_card', 'debit_card', 'how_much', 'money', 'spend', 'under']
#
# 113_1	132_7	帳單這次金額多少
# ['bill', 'current', 'how_much', 'money', 'under']
#
# 113_1	132_7	帳單這次金額多少錢
# ['bill', 'current', 'how_much', 'money', 'under']
#
# 113_1	111_4	帳單這次要繳多少
# ['bill', 'current', 'how_much', 'pay', 'under']
#
# 113_2	113_1	未繳的最低金額至少要繳多少
# ['dept', 'how_much', 'min', 'money', 'pay', 'under']
#
# 113_3	132_2	帳單過期時間
# ['bill', 'installment']
#
# 113_3	111_3	我的帳單幾號截止
# ['bill', 'date']
#
# 113_3	111_3	我的帳單截止日幾號
# ['bill', 'date']
#
# 113_3	111_3	帳單幾號截止
# ['bill', 'date']
#
# 113_3	111_3	信用卡帳單幾號截止
# ['bill', 'credit_card', 'date', 'debit_card', 'spend']
#
# 113_3	111_3	信用卡帳單截止時間
# ['bill', 'credit_card', 'debit_card', 'spend']
#
# 113_3	132_2	信用卡帳單過期時間
# ['bill', 'credit_card', 'debit_card', 'installment', 'spend']
#
# 113_3	121	信用卡最後一天什麼時候
# ['credit_card', 'date', 'debit_card', 'how', 'least', 'spend', 'when']
#
# 1121	111_1	我信用卡額度還有多少
# ['credit_card', 'debit_card', 'how_much', 'quota', 'remaining', 'spend', 'under']
#
# 1121	111_1	我刷卡額度還有多少
# ['credit_card', 'debit_card', 'how_much', 'quota', 'remaining', 'spend', 'under']
#
# 1121	111_1	現在額度有多少
# ['current', 'how_much', 'quota', 'under']
#
# 1121	111_2	現在可刷卡多少錢
# ['credit_card', 'current', 'debit_card', 'how_much', 'money', 'spend', 'under']
#
# 1121	111_2	現在能還刷多少錢
# ['current', 'how_much', 'money', 'remaining', 'spend', 'under']
#
# 1121	111_1	刷卡額度還有多少
# ['credit_card', 'debit_card', 'how_much', 'quota', 'remaining', 'spend', 'under']
#
# 1121	111_1	信用卡還有多少額度
# ['credit_card', 'debit_card', 'how_much', 'quota', 'remaining', 'spend', 'under']
#
# 1122	111_1	信用卡額度變更
# ['credit_card', 'debit_card', 'quota', 'reset', 'spend']
#
# 1122	111_1	卡片額度不夠
# ['credit_card', 'debit_card', 'quota', 'under']
#
# 1122	111_1	提高卡片額度
# ['credit_card', 'debit_card', 'quota']
#
# 1122	10	增加信用卡每月可刷費用
# ['bill', 'credit_card', 'debit_card', 'pay', 'spend']
#
# 1122	111_1	提高每月可刷卡金額
# ['credit_card', 'debit_card', 'money', 'spend']
#
# 118	111_6	寄送信用卡繳款紙本帳單
# ['bill', 'credit_card', 'debit_card', 'give', 'paper', 'pay', 'send', 'spend']
#
# 118	113_3	信用卡帳單幫我寄到我的地址
# ['bill', 'credit_card', 'debit_card', 'send', 'spend']
#
# 114_2	132_2	本期簡訊帳單補發
# ['bill', 'current', 'installment', 'makeup', 'send', 'sms']
#
# 116	111_7	我想用語音申請本行帳戶繳卡費
# ['account', 'bid', 'bill', 'credit_card', 'debit_card', 'esun', 'pay', 'spend', 'voice']
#
# 116	111_6	我想用我的帳號語音繳卡費
# ['account', 'bill', 'credit_card', 'debit_card', 'info', 'pay', 'spend', 'voice']
#
# 121	10	新信用卡幫寄送
# ['credit_card', 'debit_card', 'give', 'send', 'spend']
#
# 121	31_5	寫聯徵審核中
# ['examine']
#
# 121	10	請問有收到申請信用卡的補件資料嗎？
# ['bid', 'credit_card', 'debit_card', 'doubt', 'makeup', 'send', 'spend']
#
# 121	20	多久能收到卡片
# ['credit_card', 'debit_card']
#
# 121	20	申辦卡片流程
# ['bid', 'credit_card', 'debit_card']
#
# 121	#10	尚未收到新申辦信用卡
# ['bid', 'credit_card', 'debit_card', 'loss', 'nagative', 'spend']
#
# 123	121	我想開信用卡
# ['credit_card', 'debit_card', 'spend']
#
# 123	121	我想要開信用卡
# ['credit_card', 'debit_card', 'spend']
#
# 123	136	新戶開卡密碼
# ['activate', 'credit_card', 'debit_card', 'password']
#
# 132_1	111_3	信用卡分期
# ['credit_card', 'debit_card', 'installment', 'spend']
#
# 132_1	111_3	我要信用卡分期
# ['credit_card', 'debit_card', 'installment', 'spend']
#
# 132_1	132_3	信用卡有零利率分期嗎
# ['credit_card', 'debit_card', 'doubt', 'installment', 'interest_rate', 'spend']
#
# 132_1	10	信用卡分期怎麼申請
# ['bid', 'credit_card', 'debit_card', 'how', 'installment', 'spend']
#
# 132_1	111_3	我的信用卡要分期
# ['credit_card', 'debit_card', 'installment', 'spend']
#
# 132_2	132_7	信用卡帳單如何申請分期
# ['bid', 'bill', 'credit_card', 'debit_card', 'how', 'installment', 'spend']
#
# 132_2	20	帳單分期有額度限制嗎
# ['bill', 'doubt', 'installment', 'quota']
#
# 132_3	132_6	如果刷pi拍錢包信用卡付保費可以分期嗎
# ['bill', 'credit_card', 'debit_card', 'doubt', 'installment', 'insurance', 'money', 'spend']
#
# 132_3	132_6	用PI卡刷保費一定要分期才會給1.5%回饋嗎
# ['bill', 'credit_card', 'debit_card', 'doubt', 'installment', 'insurance', 'spend']
#
# 132_4	111_3	刷國民旅遊卡要分期
# ['credit_card', 'debit_card', 'installment', 'spend', 'travel']
#
# 132_4	132_3	刷國旅卡分期還有回饋嗎
# ['credit_card', 'debit_card', 'doubt', 'installment', 'remaining', 'spend']
#
# 132_4	10	刷國旅卡設定分期還可以請領補助嗎
# ['credit_card', 'debit_card', 'doubt', 'installment', 'makeup', 'remaining', 'reset', 'send', 'spend']
#
# 132_4	10	用國旅卡刷醫療費用可以分期嗎
# ['bill', 'credit_card', 'debit_card', 'doubt', 'installment', 'pay', 'spend']
#
# 132_5	111_3	南山聯名卡刷保險可以分幾期
# ['credit_card', 'debit_card', 'installment', 'insurance', 'spend']
#
# 132_5	132_3	南山聯名卡刷保險以外可以分期免息嗎
# ['credit_card', 'debit_card', 'doubt', 'installment', 'insurance', 'spend']
#
# 132_6	132_3	保險金額信用卡分期
# ['credit_card', 'debit_card', 'installment', 'insurance', 'money', 'spend']
#
# 133_1	131	預借現金分期要電洽客服
# ['cash_advance', 'installment', 'money']
#
# 133_1	133_3	預借現金手續費告訴
# ['bill', 'cash_advance', 'handling_fee', 'money']
#
# 133_2	133_1	信用卡借錢的密碼
# ['cash_advance', 'credit_card', 'debit_card', 'money', 'password', 'spend']
#
# 133_2	133_1	忘記ATM信用卡借錢密碼
# ['cash_advance', 'credit_card', 'debit_card', 'money', 'password', 'spend', 'forget']
#
# 134	133_1	可借用現金
# ['cash_advance', 'money', 'spend']
#
# 134	133_1	借用現金查詢
# ['cash_advance', 'money', 'query', 'spend']
#
# 134	133_1	我要預借現金
# ['cash_advance', 'money']
#
# 134	133_1	卡片借用現金
# ['cash_advance', 'credit_card', 'debit_card', 'money', 'spend']
#
# #32	#31	車子需要拖吊
# ['need', 'road_assist']
#
# #32	#31	請問有免費拖吊
# ['bill', 'road_assist']
#
# 14_1	31_5	歡樂199
# []
#
# 14_1	31_5	點數說明
# []
#
# 14_4	31_5	贈送旅平險
# ['give']
#
# 14_4	31_5	贈送不便險
# ['give']
#
# 14_4	132_3	持卡享有保險
# ['credit_card', 'debit_card', 'insurance']
#
# 14_4	132_6	出國保險
# ['insurance']
#
# 14_5	14_2	我的信用卡可以免費市區停車嗎
# ['bill', 'credit_card', 'debit_card', 'doubt', 'parking', 'spend']
#
# 14_5	121	信用卡要怎樣才可以免費市區停車
# ['bill', 'credit_card', 'debit_card', 'how', 'parking', 'spend', 'state']
#
# 14_5	14_2	免費市區停車的條件是什麼
# ['bill', 'how', 'parking']
#
# 14_5	14_2	可以用紅利折抵市區停車嗎
# ['discount', 'doubt', 'parking', 'spend']
#
# 151	153	我的卡片能享有哪種接送
# ['credit_card', 'debit_card', 'give', 'pickup']
#
# 151	132_7	自費接送
# ['bill', 'give', 'pickup']
#
# 151	153	卡片專屬接送
# ['credit_card', 'debit_card', 'give', 'pickup']
#
# 151	14_1	卡片專屬接送優惠
# ['credit_card', 'debit_card', 'discount', 'give', 'pickup']
#
# 151	152	我要預約機場接送
# ['airport', 'airport_pickup', 'give', 'pickup', 'reserve']
#
# 152	133_3	機場接送的費用
# ['airport', 'airport_pickup', 'bill', 'give', 'pay', 'pickup', 'spend']
#
# 212	10	今天補票金額
# ['makeup', 'money', 'send']
#
# 212	10	查詢今天補票金額
# ['makeup', 'money', 'query', 'send']
#
# 212	10	今天補票金額
# ['makeup', 'money', 'send']
#
# 213	10	存款明細快點傳來
# ['deposit', 'detail', 'send']
#
# 213	10	快點傳來存款明細
# ['deposit', 'detail', 'send']
#
# 222	221	我要轉帳到非本行的帳號
# ['account', 'esun', 'forward', 'info', 'transfer']
#
# 222	111_5	我要跨轉
# ['forward']
#
# 242	241	這期貸款多少錢
# ['bank_business', 'current', 'how_much', 'installment', 'loan', 'money', 'under']
#
# 31_1	111_5	數位帳戶可以當交割戶嗎
# ['account', 'delivery', 'digital', 'doubt', 'pay']
#
# 31_1	218	網路怎麼開戶
# ['how', 'web']
#
# 31_4	111_1	淘寶額度提高
# ['quota']
#
# 31_4	31_5	淘寶怎麼買
# ['how']
#
# 31_4	121	淘寶退款進度
# ['state']
#
# 31_4	211	淘寶退款帳號設定
# ['account', 'info', 'reset']
#
# 31_4	31_5	淘寶退款要多久
# []
#
# 31_5	241	PayPal要領錢
# ['money']
#
# 31_5	241	PayPal的錢要領出來
# ['money']
#
# 31_5	241	PayPal有錢要領出來
# ['money']
#
# 31_5	241	PayPal的錢怎麼領出來
# ['how', 'money']
#
# 131	241	卡片信貸
# ['credit_card', 'debit_card', 'loan']
#
# 131	111_1	卡友貸款額度上限
# ['bank_business', 'card_loan', 'credit_card', 'debit_card', 'loan', 'quota']
#
# 153	152	我想變更機場接送預約
# ['airport', 'airport_pickup', 'give', 'pickup', 'reserve', 'reset']
#
# 153	152	如何變更機場接送預約
# ['airport', 'airport_pickup', 'give', 'how', 'pickup', 'reserve', 'reset']
#
# 153	152	班機取消所以要取消預約機場接送
# ['airport', 'airport_pickup', 'give', 'pickup', 'reserve', 'take']
#
# 218	31_5	票信客服
# ['ticket']
#
# 218	31_5	支照
# []
#
# #10	1121	我信用卡被盜刷了
# ['credit_card', 'debit_card', 'spend']
#
# #10	121	弄丟信用卡
# ['credit_card', 'debit_card', 'spend']
#
# #2	#10	存摺跟金融卡遺失
# ['credit_card', 'debit_card', 'loss']
#
# #2	#10	未成年掛失金融卡
# ['credit_card', 'debit_card', 'loss']
#
# 10	121	退件信用卡
# ['credit_card', 'debit_card', 'spend']
#
# 10	14_1	換卡退回
# ['credit_card', 'debit_card', 'exchange']
#
# 10	20	續卡沒有收退回去
# ['credit_card', 'debit_card', 'nagative', 'over']
#
# 10	121	信用卡損壞
# ['credit_card', 'debit_card', 'spend']
#
# 10	111_1	信用卡額度問題
# ['credit_card', 'debit_card', 'quota', 'spend']
#
# 10	121	信用卡感應不良
# ['credit_card', 'debit_card', 'spend']
#
# 10	#10	信用卡遺失
# ['credit_card', 'debit_card', 'loss', 'spend']
#
# 10	31_5	安全碼模糊
# []
#
# 10	1122	信用卡額度調高
# ['adjust', 'credit_card', 'debit_card', 'quota', 'spend']
#
# 10	14_1	信用卡優惠問題
# ['credit_card', 'debit_card', 'discount', 'spend']
#
# 10	14_1	信用卡紅利點數查詢
# ['credit_card', 'debit_card', 'discount', 'query', 'spend']
#
# 20	10	國外可以刷簽帳卡嗎
# ['credit_card', 'debit_card', 'doubt', 'spend']
#
# 20	1121	請問debit卡有限額嗎
# ['credit_card', 'debit_card', 'doubt', 'quota']
#
# 20	#10	新申請的debit卡還沒收到首刷禮
# ['bid', 'credit_card', 'debit_card', 'loss', 'nagative', 'over', 'remaining', 'spend']
#
# 20	111_5	我要轉銀行專人
# ['forward']
#
# 20	111_5	銀行客服怎麼轉
# ['forward', 'how']
# 0.6733576642335767
